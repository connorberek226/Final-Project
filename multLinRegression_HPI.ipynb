# %%
 # %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
weather = pd.read_csv("Resources/StateWeatherByYearPredicted2.csv")
disaster = pd.read_csv("Resources/StateDisasterByYearPredicted.csv")
hpi = pd.read_csv("Resources/StateHPIByYearPredicted.csv")

hpi
# Out:
#      Unnamed: 0  HPI (Predicted)  Year       State
# 0            50       411.534827  1996  California
# 1            51       352.729579  1997  California
# 2            52       376.879986  1998  California
# 3            53       323.461683  1999  California
# 4            54       525.923849  2000  California
# ..          ...              ...   ...         ...
# 367         169       240.895108  2115    Illinois
# 368         170       253.791300  2116    Illinois
# 369         171       248.828342  2117    Illinois
# 370         172       245.923808  2118    Illinois
# 371         173       242.397584  2119    Illinois
#
# [372 rows x 4 columns]

# %%
weather_disaster = weather.merge(disaster, how="outer", on=["State", "Year"])

weather_disaster.head(25)
# Out:
#     Unnamed: 0_x  Year       State  Average Weather (F, Predicted)  \
# 0              0  1996  California                       58.026152
# 1              1  1997  California                       58.236920
# 2              2  1998  California                       58.122479
# 3              3  1999  California                       58.100723
# 4              4  2000  California                       58.165753
# 5              5  2001  California                       58.433510
# 6              6  2002  California                       58.161562
# 7              7  2003  California                       58.376363
# 8              8  2004  California                       58.281721
# 9              9  2005  California                       58.123838
# 10            10  2006  California                       58.301163
# 11            11  2007  California                       58.572952
# 12            12  2008  California                       58.557361
# ...

# %%
weather_disaster_hpi = weather_disaster.merge(hpi, how="outer", on=["State", "Year"])

weather_disaster_hpi = weather_disaster_hpi[["Year", "State", "Average Weather (F, Predicted)", "Total_Disasters (Predicted)", "HPI (Predicted)"]]

weather_disaster_hpi
# Out:
#      Year       State  Average Weather (F, Predicted)  \
# 0    1996  California                       58.026152
# 1    1997  California                       58.236920
# 2    1998  California                       58.122479
# 3    1999  California                       58.100723
# 4    2000  California                       58.165753
# ..    ...         ...                             ...
# 367  2115    Illinois                       56.222767
# 368  2116    Illinois                       57.025033
# 369  2117    Illinois                       56.197010
# 370  2118    Illinois                       57.027116
# 371  2119    Illinois                       56.532533
#
#      Total_Disasters (Predicted)  HPI (Predicted)
# 0                      81.475365       411.534827
# 1                      62.247990       352.729579
# 2                      31.755943       376.879986
# 3                      38.874983       323.461683
# 4                      58.250681       525.923849
# ...

# %%
# Assign the data to X and y

X = weather_disaster_hpi[["Average Weather (F, Predicted)", "Total_Disasters (Predicted)"]]
y = weather_disaster_hpi["HPI (Predicted)"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (372, 2) (372, 1)

# %%
# Use train_test_split to create training and testing data

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

### END SOLUTION

# %%
 # Create the model using LinearRegression

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
### END SOLUTION

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.47678810312717473
# Testing Score: 0.4465524563936246
